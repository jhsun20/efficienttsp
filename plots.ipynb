# %% [markdown]
# Greedy

# %%
import matplotlib.pyplot as plt

# Sample data
losses = [1.054, 0.3666, 0.3214, 0.304, 0.2898, 0.2797, 0.2684, 0.257, 0.2467, 0.2333]
costs20 = [4.266, 4.236, 4.239, 4.247, 4.266, 4.314, 4.331, 4.352, 4.36, 4.373]
gaps20 = [11.393, 10.573, 10.648, 10.83, 11.311, 12.599, 13.045, 13.6, 13.802, 14.176]
costs50 = [7.331, 7.131, 7.144, 7.362, 7.657, 7.973, 8.205, 8.263, 8.299, 8.3]
gaps50 = [28.82, 25.319, 25.535, 29.359, 34.56, 40.135, 44.224, 45.247, 45.88, 45.914]

# Plotting
plt.plot(losses, label='CE Loss')
plt.plot(gaps20, label='TSP 20 Gap')
plt.plot(gaps50, label='TSP 50 Gap')

# Adding labels and title
plt.xlabel('Epochs')
plt.ylabel('Loss/Optimality Gap (%)')
plt.title('Joshi Training')
plt.legend()

# Show plot
plt.show()
